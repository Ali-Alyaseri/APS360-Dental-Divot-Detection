# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/farazimran18/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14358, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 14358 (delta 14), reused 34 (delta 3), pack-reused 14289 (from 4)
# Receiving objects: 100% (14358/14358), 44.09 MiB | 41.81 MiB/s, done.
# Resolving deltas: 100% (9550/9550), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -qr requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.7 MB/s eta 0:00:00

# %%
# !python detect.py \
    --weights /content/yolov5/runs/train/exp7/weights/best.pt \
    --source /content/drive/MyDrive/split_medium/test/images
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/drive/MyDrive/split_medium/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 ff3ca6b Python-3.11.13 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# ...

# %%
# !python val.py --weights runs/train/exp7/weights/best.pt --data data/cavity_dataset.yaml --task test
# Out:
# val: data=data/cavity_dataset.yaml, weights=['runs/train/exp7/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 ff3ca6b Python-3.11.13 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s_cbam summary: 169 layers, 7014459 parameters, 0 gradients, 15.8 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 53.9MB/s]
# test: Scanning /content/drive/MyDrive/split_medium/test/labels.cache... 61 images, 0 backgrounds, 0 corrupt: 100% 61/61 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:12<00:00,  6.40s/it]
#                    all         61        126      0.843      0.727      0.794      0.441
# ...

# %%
# !python val.py --weights runs/train/exp7/weights/best.pt --data data/cavity_dataset.yaml --task train --name lol
# Out:
# val: data=data/cavity_dataset.yaml, weights=['runs/train/exp7/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=train, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=lol, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 ff3ca6b Python-3.11.13 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5s_cbam summary: 169 layers, 7014459 parameters, 0 gradients, 15.8 GFLOPs
# train: Scanning /content/drive/MyDrive/split_medium/train/labels.cache... 480 images, 0 backgrounds, 0 corrupt: 100% 480/480 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 15/15 [01:21<00:00,  5.44s/it]
#                    all        480        883      0.907      0.924       0.97      0.628
# Speed: 0.8ms pre-process, 114.0ms inference, 0.6ms NMS per image at shape (32, 3, 640, 640)
# ...
